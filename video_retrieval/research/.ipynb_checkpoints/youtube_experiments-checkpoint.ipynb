# %%
from googleapiclient.discovery import build

# %%
# Replace 'YOUR_API_KEY' with the API key you obtained from the Google Cloud Console
api_key = 'AIzaSyBuzce18QB3S12aEVpdz5-n5rGPPorfhFg'
youtube = build('youtube', 'v3', developerKey=api_key)

def search_videos(query, max_results=5):
    request = youtube.search().list(
        part='snippet',
        q=query,
        type='video',
        maxResults=max_results
    )

    response = request.execute()
    return response['items']

if __name__ == "__main__":
    search_query = input("Enter your search query: ")
    results = search_videos(search_query)

    for video in results:
        video_id = video['id']['videoId']
        video_title = video['snippet']['title']
        print(f"{video_title} - https://www.youtube.com/watch?v={video_id}")
# Out:
# Enter your search query:  carboxylic acid
# GCSE Chemistry - Carboxylic Acids #58 - https://www.youtube.com/watch?v=ED9EU3FfzyU
# Naming Carboxylic Acids - IUPAC Nomenclature - Organic Chemistry - https://www.youtube.com/watch?v=EEj2-RZZCGE
# Carboxylic acid introduction | Carboxylic acids and derivatives | Organic chemistry | Khan Academy - https://www.youtube.com/watch?v=xheOq0XZ-so
# Carboxylic Acids: Crash Course Organic Chemistry #30 - https://www.youtube.com/watch?v=cA0fGIfALxI
# Carboxylic Acids and Their Derivatives - https://www.youtube.com/watch?v=iU0yt2XkUCU

# %%
import os
from googleapiclient.discovery import build

# Replace 'YOUR_API_KEY' with your actual YouTube Data API key
API_KEY = 'AIzaSyBuzce18QB3S12aEVpdz5-n5rGPPorfhFg'

def get_video_captions(video_id):
    youtube = build('youtube', 'v3', developerKey=API_KEY)

    # Get captions list for the video
    captions_response = youtube.captions().list(
        part='snippet',
        videoId=video_id
    ).execute()

    # Check if captions exist for the video
    if 'items' in captions_response:
        captions_items = captions_response['items']
        if captions_items:
            # Get the first caption track (usually the automatic captions)
            caption_track_id = captions_items[0]['id']
            
            # Retrieve the actual caption content
            caption_content = youtube.captions().download(
                id=caption_track_id,
                tfmt='srt'  # SRT format for captions
            ).execute()

            return caption_content
    return None

if __name__ == "__main__":
    video_id = 'ED9EU3FfzyU'
    captions = get_video_captions(video_id)

    if captions:
        # Save the captions to a file
        output_file = f'{video_id}_captions.srt'
        with open(output_file, 'wb') as f:
            f.write(captions)
        print(f"Captions saved to '{output_file}'.")
    else:
        print("Captions not available for this video.")
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[6], line 34
#      32 if __name__ == "__main__":
#      33     video_id = 'ED9EU3FfzyU'
# ---> 34     captions = get_video_captions(video_id)
#      36     if captions:
#      37         # Save the captions to a file
#      38         output_file = f'{video_id}_captions.srt'
#
# Cell In[6], line 24, in get_video_captions(video_id)
#      21         caption_track_id = captions_items[0]['id']
#      23         # Retrieve the actual caption content
# ---> 24         caption_content = youtube.captions().download(
#      25             id=caption_track_id,
#      26             tfmt='srt'  # SRT format for captions
#      27         ).execute()
#      29         return caption_content
#      30 return None
#
# File ~/Desktop/Computer Science/Projects/lesson_generator/video_retrieval/video_ret/lib/python3.9/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/Desktop/Computer Science/Projects/lesson_generator/video_retrieval/video_ret/lib/python3.9/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 401 when requesting https://youtube.googleapis.com/youtube/v3/captions/AUieDaaHS5HBEGvqaypkPtL_OkEf5LYspsjfYt_wt5lLBqaHwng?tfmt=srt&key=AIzaSyBuzce18QB3S12aEVpdz5-n5rGPPorfhFg returned "API keys are not supported by this API. Expected OAuth2 access token or other authentication credentials that assert a principal. See https://cloud.google.com/docs/authentication". Details: "[{'message': 'Login Required.', 'domain': 'global', 'reason': 'required', 'location': 'Authorization', 'locationType': 'header'}]">

# %%
# !pip install youtube-transcript-api
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-0.6.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in /Users/alirezakafaei/Desktop/Computer Science/Projects/lesson_generator/video_retrieval/video_ret/lib/python3.9/site-packages (from youtube-transcript-api) (2.31.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alirezakafaei/Desktop/Computer Science/Projects/lesson_generator/video_retrieval/video_ret/lib/python3.9/site-packages (from requests->youtube-transcript-api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alirezakafaei/Desktop/Computer Science/Projects/lesson_generator/video_retrieval/video_ret/lib/python3.9/site-packages (from requests->youtube-transcript-api) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alirezakafaei/Desktop/Computer Science/Projects/lesson_generator/video_retrieval/video_ret/lib/python3.9/site-packages (from requests->youtube-transcript-api) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alirezakafaei/Desktop/Computer Science/Projects/lesson_generator/video_retrieval/video_ret/lib/python3.9/site-packages (from requests->youtube-transcript-api) (2023.7.22)
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-0.6.1
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Users/alirezakafaei/Desktop/Computer Science/Projects/lesson_generator/video_retrieval/video_ret/bin/python3 -m pip install --upgrade pip' command.

# %%
from youtube_transcript_api import YouTubeTranscriptApi

YouTubeTranscriptApi.get_transcript(video_id)
# Out:
# [{'text': "in this video we're going to cover",
#   'start': 4.96,
#   'duration': 4.08},
#  {'text': 'carboxylic acids', 'start': 6.56, 'duration': 5.039},
#  {'text': 'just like alkanes and alcohols', 'start': 9.04, 'duration': 5.519},
#  {'text': 'carboxylic acids are a homologous series',
#   'start': 11.599,
#   'duration': 5.68},
#  {'text': 'of organic compounds', 'start': 14.559, 'duration': 4.88},
#  {'text': 'but importantly they have the functional',
#   'start': 17.279,
#   'duration': 5.361},
#  {'text': 'group c-o-o-h', 'start': 19.439, 'duration': 7.201},
#  {'text': 'and their names all end in anoic acid',
#   'start': 22.64,
#   'duration': 7.52},
#  {'text': 'so this one which has three carbons is',
#   'start': 26.64,
#   'duration': 6.48},
#  {'text': 'called propanoic acid', 'start': 30.16, 'duration': 5.04},
#  {'text': 'and in order the other ones you need to',
#   'start': 33.12,
#   'duration': 4.56},
#  {'text': 'know are methanoic acid', 'start': 35.2, 'duration': 4.4},
#  {'text': 'ethanoic acid', 'start': 37.68, 'duration': 5.28},
#  {'text': 'and finally butanoic acid', 'start': 39.6, 'duration': 5.04},
#  {'text': 'and one thing to remember is that when',
#   'start': 42.96,
#   'duration': 3.439},
#  {'text': 'you write their formulas you should',
#   'start': 44.64,
#   'duration': 4.399},
#  {'text': 'always put the c o h groups together at',
#   'start': 46.399,
#   'duration': 5.921},
#  {'text': 'the end like we have here', 'start': 49.039, 'duration': 3.281},
#  {'text': 'as you can probably tell from their',
#   'start': 52.399,
#   'duration': 2.48},
#  {'text': 'names', 'start': 53.92, 'duration': 3.04},
#  {'text': 'these are all acids', 'start': 54.879, 'duration': 5.441},
#  {'text': 'and so they react like any other acid',
#   'start': 56.96,
#   'duration': 6.32},
#  {'text': 'however they are all weak acids', 'start': 60.32, 'duration': 5.92},
#  {'text': "so they don't fully ionize", 'start': 63.28, 'duration': 4.72},
#  {'text': 'which means that their carboxylic acid',
#   'start': 66.24,
#   'duration': 4.16},
#  {'text': "molecules don't all release their",
#   'start': 68.0,
#   'duration': 5.36},
#  {'text': 'hydrogen ions because of this we show',
#   'start': 70.4,
#   'duration': 5.039},
#  {'text': 'their ionization with equations like',
#   'start': 73.36,
#   'duration': 3.439},
#  {'text': 'this', 'start': 75.439, 'duration': 3.601},
#  {'text': 'with an equilibrium arrow between the',
#   'start': 76.799,
#   'duration': 4.32},
#  {'text': 'full acid on the left', 'start': 79.04, 'duration': 4.32},
#  {'text': 'and the ionized version where it lost',
#   'start': 81.119,
#   'duration': 5.841},
#  {'text': 'its hydrogen on the right', 'start': 83.36, 'duration': 5.28},
#  {'text': 'the other thing to know is that these',
#   'start': 86.96,
#   'duration': 3.44},
#  {'text': 'negative ions that they form when they',
#   'start': 88.64,
#   'duration': 6.24},
#  {'text': 'ionize have names that end in anoate',
#   'start': 90.4,
#   'duration': 8.24},
#  {'text': 'so propanoic acid like we have here',
#   'start': 94.88,
#   'duration': 7.36},
#  {'text': 'will ionize into a propanoate ion',
#   'start': 98.64,
#   'duration': 6.88},
#  {'text': 'and a hydrogen ion', 'start': 102.24, 'duration': 3.28},
#  {'text': 'like other acids if we react a',
#   'start': 107.92,
#   'duration': 6.159},
#  {'text': 'carboxylic acid with a metal carbonate',
#   'start': 110.479,
#   'duration': 5.68},
#  {'text': 'it will form a salt', 'start': 114.079, 'duration': 3.121},
#  {'text': 'water', 'start': 116.159, 'duration': 4.32},
#  {'text': 'and carbon dioxide', 'start': 117.2, 'duration': 3.279},
#  {'text': 'so if we reacted to ethanoic acid with',
#   'start': 120.799,
#   'duration': 5.761},
#  {'text': 'potassium carbonate for example',
#   'start': 123.759,
#   'duration': 5.601},
#  {'text': 'it would form potassium ethanoic which',
#   'start': 126.56,
#   'duration': 4.399},
#  {'text': 'is the salt', 'start': 129.36, 'duration': 2.64},
#  {'text': 'water', 'start': 130.959, 'duration': 4.241},
#  {'text': 'and carbon dioxide', 'start': 132.0, 'duration': 3.2},
#  {'text': 'the last thing we need to cover is how',
#   'start': 137.28,
#   'duration': 4.48},
#  {'text': 'carboxylic acids are made', 'start': 139.2, 'duration': 4.48},
#  {'text': "it's actually pretty simple", 'start': 141.76, 'duration': 4.8},
#  {'text': 'all we do is take an alcohol like',
#   'start': 143.68,
#   'duration': 4.24},
#  {'text': 'butanol', 'start': 146.56, 'duration': 5.28},
#  {'text': 'and oxidize it using an oxidizing agent',
#   'start': 147.92,
#   'duration': 6.88},
#  {'text': 'which basically adds an oxygen', 'start': 151.84, 'duration': 6.24},
#  {'text': 'and we end up with a carboxylic acid',
#   'start': 154.8,
#   'duration': 5.36},
#  {'text': 'which in this case would be butanoic',
#   'start': 158.08,
#   'duration': 3.36},
#  {'text': 'acid', 'start': 160.16, 'duration': 3.6},
#  {'text': 'because it still has four carbons',
#   'start': 161.44,
#   'duration': 6.28},
#  {'text': 'and so starts with butter', 'start': 163.76, 'duration': 3.96},
#  {'text': "anyway that's everything for this video",
#   'start': 170.0,
#   'duration': 5.12},
#  {'text': 'so hope you found it useful if you did',
#   'start': 172.8,
#   'duration': 4.719},
#  {'text': 'then do give us a like and subscribe',
#   'start': 175.12,
#   'duration': 6.28},
#  {'text': "and i'll see you again soon", 'start': 177.519, 'duration': 3.881},
#  {'text': 'you', 'start': 184.4, 'duration': 2.08}]
